# %%
import json
import pandas as pd

# %% [markdown]
# # Yelp Reviews

# %%
businesses = [] #this is actually review = []
for line in open('review.json', 'r'):
    businesses.append(json.loads(line))

# %%
# review df
df = pd.DataFrame(businesses)

# %%
df
# Out:
#                       review_id                 user_id  \
# 0        Q1sbwvVQXV2734tPgoKj4Q  hG7b0MtEbXx5QzbzE6C_VA
# 1        GJXCdrto3ASJOqKeVWPi6Q  yXQM5uF2jS6es16SJzNHfg
# 2        2TzJjDVDEuAW6MR5Vuc1ug  n6-Gk65cPZL6Uz8qRm3NYw
# 3        yi0R0Ugj_xUx_Nek0-_Qig  dacAIZ6fTM6mqwW5uxkskg
# 4        11a8sVPMUFtaC7_ABRkmtw  ssoyf2_x0EQMed6fgHeMyQ
# ...                         ...                     ...
# 6685895  0pCaq1hqAViS2N6ldlp_sQ  Xu_YazIajfsc7SRj1wJ6Mg
# 6685896  jPCXuSBbI_cPocgoNBhdkg  V6BjjQICDO4q7TT3ZhaPWw
# 6685897  zwzO3yPdGbdgGy3-XQ0SWg  PFiIECX8wuvi7P-1mCvIjA
# 6685898  o8Nc2BJhKJXM6tRHJDRuPA  wu5R5_N7q5iqCBh6NBX26Q
# 6685899  OKmOLFwtI-NjofTHAGzv1Q  Ej3mCvjcwVXCSPB_avIfjQ
#
#                     business_id  stars  useful  funny  cool  \
# 0        ujmEBvifdJM6h6RLv4wQIg    1.0       6      1     0
# 1        NZnhc2sEQy3RmzKTZnqtwQ    5.0       0      0     0
# 2        WTqjgwHlXbSFevF32_DJVw    5.0       3      0     0
# ...

# %%
# save reviews data into csv
df.to_csv('Yelp_Dataset_Reviews.csv')

# %% [markdown]
# # Yelp Business info

# %%
# business df
business_info = []
for line in open('business.json', 'r'):
    business_info.append(json.loads(line))

# %%
# convert business info into df
df_business_info = pd.DataFrame(business_info)
df_business_info
# Out:
#                    business_id                             name  \
# 0       1SWheh84yJXfytovILXOAQ       Arizona Biltmore Golf Club
# 1       QXAEGFB4oINsVuTFxEYKFQ       Emerald Chinese Restaurant
# 2       gnKjwL_1w79qoiV3IC_xQQ      Musashi Japanese Restaurant
# 3       xvX2CttrVhyG2z1dFg_0xw  Farmers Insurance - Paul Lorenz
# 4       HhyxOkGAM07SRYtlQ4wMFQ              Queen City Plumbing
# ...                        ...                              ...
# 192604  nqb4kWcOwp8bFxzfvaDpZQ               Sanderson Plumbing
# 192605  vY2nLU5K20Pee-FdG0br1g                         Chapters
# 192606  MiEyUDKTjeci5TMfxVZPpg                   Phoenix Pavers
# 192607  zNMupayB2jEHVDOji8sxoQ            Beasley's Barber Shop
# 192608  c1f_VAX1KIK8-JoVhjbYOw                   Oriental Relax
#
#                                address             city state postal_code  \
# 0          2818 E Camino Acequia Drive          Phoenix    AZ       85016
# ...

# %%
# save business info into csv
df_business_info.to_csv('Yelp_Dataset_Business_Info.csv')

# %% [markdown]
# # Yelp Tips

# %%
# tips df
tips = []
for line in open('tip.json', 'r'):
    tips.append(json.loads(line))

# %%
# convert tips info into df
df_tips = pd.DataFrame(tips)
df_tips
# Out:
#                         user_id             business_id  \
# 0        UPw5DWs_b-e2JRBS-t37Ag  VaKXUpmWTTWDKbpJ3aQdMw
# 1        Ocha4kZBHb4JK0lOWvE0sg  OPiPeoJiv92rENwbq76orA
# 2        jRyO2V1pA4CdVVqCIOPc1Q  5KheTjYPu1HcQzQFtm4_vw
# 3        FuTJWFYm4UKqewaosss1KA  TkoyGi8J7YFjA6SbaRzrxg
# 4        LUlKtaM3nXd-E4N4uOk_fQ  AkL6Ous6A1atZejfZXn1Bg
# ...                         ...                     ...
# 1223089  nus5X9JKgU_SzfAL4vhJrg  qdwwiRKwnhdlr9QcgJuzbg
# 1223090  95wqYGU6-OiHqRPZP0uAWw  wrs4Zbz17q_G49AIRxRPVw
# 1223091  HtLaONYabidSxMS1eGHcXA  wEc4JE2NYQr1RnGjGr4q7w
# 1223092  T4R5ZKfcGt1GIAgjCh67eA  n5Hc_iMVkyxcS0SXiBCbOQ
# 1223093  2Ag223bd4OtQOnc-F067rQ  wEoaR5WKNtLOLyR1z0TYdg
#
#                                                       text  \
# 0        Great for watching games, ufc, and whatever el...
# 1        Happy Hour 2-4 daily with 1/2 price drinks and...
# 2        Good chips and salsa. Loud at times. Good serv...
# ...

# %%
# save tips info into csv
df_tips.to_csv('Yelp_Dataset_Tips.csv')

# %% [markdown]
# # Yelp User

# %%
# User df
user = []
for line in open('user.json', 'r'):
    user.append(json.loads(line))

# %%
# convert user info into df
df_user = pd.DataFrame(user)
df_user
# Out:
#                         user_id     name  review_count        yelping_since  \
# 0        l6BmjZMeQD3rDxWUbiAiow   Rashmi            95  2013-10-08 23:11:33
# 1        4XChL029mKr5hydo79Ljxg    Jenna            33  2013-02-21 22:29:06
# 2        bc8C_eETBWL0olvFSJJd0w    David            16  2013-10-04 00:16:10
# 3        dD0gZpBctWGdWo9WlGuhlA   Angela            17  2014-05-22 15:57:30
# 4        MM4RJAeH6yuaN8oZDSt0RA    Nancy           361  2013-10-23 07:02:50
# ...                         ...      ...           ...                  ...
# 1637133  oC4BjbB4I-wx5KBAO1k2Gg   Jiaxin             2  2016-02-24 19:28:47
# 1637134  LKd_-BT2GMWp8_1ho18kOg      Wes             8  2017-02-25 23:34:05
# 1637135  ib_elCBhGOamS0AALkh4Og      Lee             4  2009-08-19 22:08:16
# 1637136  WV27LoSFDG_YmiDKTLKKLA  Melissa             1  2018-10-15 17:07:43
# 1637137  agVqH9xDhNw8n7ve66H1Uw     Erin             1  2016-03-03 21:56:06
#
#          useful  funny  cool                elite  \
# ...

# %%
# save tips info into csv
df_user.to_csv('Yelp_Dataset_User.csv')

# %% [markdown]
# # Yelp Checkin

# %%
# checkin df
checkin = []
for line in open('checkin.json', 'r'):
    checkin.append(json.loads(line))

# %%
# convert checkin info into df
df_checkin = pd.DataFrame(checkin)
df_checkin
# Out:
#                    business_id  \
# 0       --1UhMGODdWsrMastO9DZw
# 1       --6MefnULPED_I942VcFNA
# 2       --7zmmkVg-IMGaXbuVd0SQ
# 3       --8LPVSo5i0Oo61X01sV9A
# 4       --9QQLMTbFzLJ_oT-ON3Xw
# ...                        ...
# 161945  zzvlwkcNR1CCqOPXwuvz2A
# 161946  zzwaS0xn1MVEPEf0hNLjew
# 161947  zzwhN7x37nyjP0ZM8oiHmw
# 161948  zzwicjPC9g246MK2M1ZFBA
# 161949  zzzaIBwimxVej4tY6qFOUQ
#
#                                                      date
# 0       2016-04-26 19:49:16, 2016-08-30 18:36:57, 2016...
# 1       2011-06-04 18:22:23, 2011-07-23 23:51:33, 2012...
# 2       2014-12-29 19:25:50, 2015-01-17 01:49:14, 2015...
# 3                                     2016-07-08 16:43:30
# 4       2010-06-26 17:39:07, 2010-08-01 20:06:21, 2010...
# ...                                                   ...
# 161945  2017-05-06 20:05:15, 2017-05-12 22:37:03, 2017...
# 161946  2010-02-16 02:09:56, 2010-07-05 05:40:48, 2010...
# ...

# %%
# save checkin info into csv
df_checkinheckin.to_csv('Yelp_Dataset_Checkin.csv')
