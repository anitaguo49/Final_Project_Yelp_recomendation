# %%
import pandas as pd
import numpy as np
from lightfm.data import Dataset
import ast
import matplotlib.pyplot as plt
# %matplotlib inline
from lightfm import LightFM
from lightfm.evaluation import precision_at_k,auc_score,reciprocal_rank
import scipy
import time
import math
from lightfm.data import Dataset
import warnings
warnings.filterwarnings("ignore")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/lightfm/_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn('LightFM was compiled without OpenMP support. '

# %%
merged_df = pd.read_csv('merged_busi_review.csv',index_col=0).drop('Unnamed: 0.1',axis=1)
merged_df.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  Q1sbwvVQXV2734tPgoKj4Q  hG7b0MtEbXx5QzbzE6C_VA  ujmEBvifdJM6h6RLv4wQIg
# 1  8Edv5pKe5lOBoN5UZTUI1w  RBXSJA372ilErzNwz0jXvQ  ujmEBvifdJM6h6RLv4wQIg
# 2  kEs5u0cGPtiSQCLW7b0l9g  x3brMMbJrAW9PwW5A6YL5w  ujmEBvifdJM6h6RLv4wQIg
# 3  Pm6qydbW58BB0zdWCPlBmg  Skzdl0sWhW88525a1vr59g  ujmEBvifdJM6h6RLv4wQIg
# 4  QWJVYwNxUY_Plu4Ipz33_A  3Y25VDfnQVcuc33T-U3Z6A  ujmEBvifdJM6h6RLv4wQIg
#
#    rating    year       city  \
# 0     1.0  2013.0  Las Vegas
# 1     4.0  2017.0  Las Vegas
# 2     1.0  2018.0  Las Vegas
# 3     1.0  2018.0  Las Vegas
# 4     5.0  2014.0  Las Vegas
#
#                                           categories
# 0  Fitness & Instruction, Doctors, Health & Medic...
# 1  Fitness & Instruction, Doctors, Health & Medic...
# 2  Fitness & Instruction, Doctors, Health & Medic...
# 3  Fitness & Instruction, Doctors, Health & Medic...
# 4  Fitness & Instruction, Doctors, Health & Medic...

# %%
#model establishment
dataset = Dataset()
dataset.fit(merged_df.user_id,merged_df.business_id)
type(dataset)
num_users, num_items = dataset.interactions_shape()
print('Num users: {}, num_items {}.'.format(num_users, num_items))
# Out:
# Num users: 1637139, num_items 192610.

# %%
merged_df.categories = merged_df.categories.astype(str)

# %%
list1 = list(merged_df.categories)
set(list1)
# Out:
# {'Fashion, Shopping, Department Stores, Discount Store',
#  'Endodontists, Health & Medical, Oral Surgeons, Dentists, General Dentistry, Cosmetic Dentists',
#  'Italian, Pizza, Restaurants, Food, Food Delivery Services',
#  'Trainers, Active Life, Fitness & Instruction, Gyms, Martial Arts',
#  'Advertising, Professional Services, Signmaking, Graphic Design',
#  'Shopping, Jewelry, Jewelry Repair, Watches, Local Services, Professional Services',
#  'Hotels & Travel, Arts & Entertainment, Museums, Tours, Walking Tours',
#  'Event Planning & Services, Marketing, Professional Services, Party Equipment Rentals, Party & Event Planning',
#  'Automotive, Auto Repair, Oil Change Stations, Tires',
#  'Web Design, Professional Services, Marketing, Public Relations, Advertising',
#  'Home & Garden, Shopping, Home Decor, Hardware Stores, Paint Stores, Home Services, Building Supplies',
# ...

# %%
list1
# Out:
# ['Fitness & Instruction, Doctors, Health & Medical, Active Life, Gyms, Emergency Rooms, Medical Centers, Hospitals',
#  'Fitness & Instruction, Doctors, Health & Medical, Active Life, Gyms, Emergency Rooms, Medical Centers, Hospitals',
#  'Fitness & Instruction, Doctors, Health & Medical, Active Life, Gyms, Emergency Rooms, Medical Centers, Hospitals',
#  'Fitness & Instruction, Doctors, Health & Medical, Active Life, Gyms, Emergency Rooms, Medical Centers, Hospitals',
#  'Fitness & Instruction, Doctors, Health & Medical, Active Life, Gyms, Emergency Rooms, Medical Centers, Hospitals',
#  'Fitness & Instruction, Doctors, Health & Medical, Active Life, Gyms, Emergency Rooms, Medical Centers, Hospitals',
#  'Fitness & Instruction, Doctors, Health & Medical, Active Life, Gyms, Emergency Rooms, Medical Centers, Hospitals',
#  'Fitness & Instruction, Doctors, Health & Medical, Active Life, Gyms, Emergency Rooms, Medical Centers, Hospitals',
# ...
